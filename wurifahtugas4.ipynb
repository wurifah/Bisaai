# %% [markdown]
# <a href="https://colab.research.google.com/github/wurifah/Bisaai/blob/main/wurifahtugas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data covid jakarta maret-mei.csv')
df
# Out:
#         tanggal          diagnosa  jumlah
# 0    2020-03-01  Meninggal Harian       0
# 1    2020-03-01     Sembuh Harian       0
# 2    2020-03-01    Positif Harian       0
# 3    2020-03-02  Meninggal Harian       0
# 4    2020-03-02     Sembuh Harian       0
# ..          ...               ...     ...
# 271  2020-05-30     Sembuh Harian     196
# 272  2020-05-30    Positif Harian      98
# 273  2020-05-31  Meninggal Harian       1
# 274  2020-05-31     Sembuh Harian      99
# 275  2020-05-31    Positif Harian     121
#
# [276 rows x 3 columns]

# %%
# seleksi data positif
positif = df[df['diagnosa'] =='Positif Harian']
positif
# Out:
#         tanggal        diagnosa  jumlah
# 2    2020-03-01  Positif Harian       0
# 5    2020-03-02  Positif Harian       0
# 8    2020-03-03  Positif Harian       3
# 11   2020-03-04  Positif Harian       0
# 14   2020-03-05  Positif Harian       4
# ..          ...             ...     ...
# 263  2020-05-27  Positif Harian     137
# 266  2020-05-28  Positif Harian     103
# 269  2020-05-29  Positif Harian     124
# 272  2020-05-30  Positif Harian      98
# 275  2020-05-31  Positif Harian     121
#
# [92 rows x 3 columns]

# %%
#plotting data positif
positif.plot(x='tanggal',y='jumlah', kind = 'bar', color =  'blue',figsize=(20,10))
plt.show()

# %%
#seleksi data meninggal
meninggal = df[df['diagnosa'] =='Meninggal Harian']
meninggal
# Out:
#         tanggal          diagnosa  jumlah
# 0    2020-03-01  Meninggal Harian       0
# 3    2020-03-02  Meninggal Harian       0
# 6    2020-03-03  Meninggal Harian       1
# 9    2020-03-04  Meninggal Harian       0
# 12   2020-03-05  Meninggal Harian       2
# ..          ...               ...     ...
# 261  2020-05-27  Meninggal Harian       2
# 264  2020-05-28  Meninggal Harian       4
# 267  2020-05-29  Meninggal Harian       3
# 270  2020-05-30  Meninggal Harian       2
# 273  2020-05-31  Meninggal Harian       1
#
# [92 rows x 3 columns]

# %%
#plotting data meninggal
meninggal.plot(x='tanggal',y='jumlah', kind = 'bar', color = 'red',figsize=(20,10))
plt.show()

# %%
#seleksi data sembuh
sembuh = df[df['diagnosa'] =='Sembuh Harian']
sembuh
# Out:
#         tanggal       diagnosa  jumlah
# 1    2020-03-01  Sembuh Harian       0
# 4    2020-03-02  Sembuh Harian       0
# 7    2020-03-03  Sembuh Harian       0
# 10   2020-03-04  Sembuh Harian       0
# 13   2020-03-05  Sembuh Harian       0
# ..          ...            ...     ...
# 262  2020-05-27  Sembuh Harian      20
# 265  2020-05-28  Sembuh Harian      21
# 268  2020-05-29  Sembuh Harian      88
# 271  2020-05-30  Sembuh Harian     196
# 274  2020-05-31  Sembuh Harian      99
#
# [92 rows x 3 columns]

# %%
#plotting data sembuh
sembuh.plot(x='tanggal',y='jumlah', kind = 'bar', color = 'green',figsize=(20,10))
plt.show()

# %%
#plotting data positif, meninggal dan sembuh
plt.figure(figsize=(20,10))
plt.bar(positif.tanggal,positif.jumlah, color = 'blue')
plt.bar(meninggal.tanggal,meninggal.jumlah, color = 'red')
plt.bar(sembuh.tanggal,sembuh.jumlah, color = 'green')
plt.xticks(rotation=90)
plt.show()

# %%
#menghitung jumlah kumulatif
df['jumlahkumulatif'] = df.groupby('diagnosa')['jumlah'].cumsum()
df
# Out:
#         tanggal          diagnosa  jumlah  jumlahkumulatif
# 0    2020-03-01  Meninggal Harian       0                0
# 1    2020-03-01     Sembuh Harian       0                0
# 2    2020-03-01    Positif Harian       0                0
# 3    2020-03-02  Meninggal Harian       0                0
# 4    2020-03-02     Sembuh Harian       0                0
# ..          ...               ...     ...              ...
# 271  2020-05-30     Sembuh Harian     196             2003
# 272  2020-05-30    Positif Harian      98             7151
# 273  2020-05-31  Meninggal Harian       1              520
# 274  2020-05-31     Sembuh Harian      99             2102
# 275  2020-05-31    Positif Harian     121             7272
#
# [276 rows x 4 columns]

# %%
#jumlah kumulatif positif
positif = df[df['diagnosa'] =='Positif Harian']
positif
# Out:
#         tanggal        diagnosa  jumlah  jumlahkumulatif
# 2    2020-03-01  Positif Harian       0                0
# 5    2020-03-02  Positif Harian       0                0
# 8    2020-03-03  Positif Harian       3                3
# 11   2020-03-04  Positif Harian       0                3
# 14   2020-03-05  Positif Harian       4                7
# ..          ...             ...     ...              ...
# 263  2020-05-27  Positif Harian     137             6826
# 266  2020-05-28  Positif Harian     103             6929
# 269  2020-05-29  Positif Harian     124             7053
# 272  2020-05-30  Positif Harian      98             7151
# 275  2020-05-31  Positif Harian     121             7272
#
# [92 rows x 4 columns]

# %%
#plotting jumlah kumulatif positif
positif.plot(x='tanggal',y='jumlahkumulatif', kind = 'line',figsize=(10,5))
plt.show()

# %%
#jumlah kumulatif meninggal
meninggal = df[df['diagnosa'] =='Meninggal Harian']
meninggal
# Out:
#         tanggal          diagnosa  jumlah  jumlahkumulatif
# 0    2020-03-01  Meninggal Harian       0                0
# 3    2020-03-02  Meninggal Harian       0                0
# 6    2020-03-03  Meninggal Harian       1                1
# 9    2020-03-04  Meninggal Harian       0                1
# 12   2020-03-05  Meninggal Harian       2                3
# ..          ...               ...     ...              ...
# 261  2020-05-27  Meninggal Harian       2              510
# 264  2020-05-28  Meninggal Harian       4              514
# 267  2020-05-29  Meninggal Harian       3              517
# 270  2020-05-30  Meninggal Harian       2              519
# 273  2020-05-31  Meninggal Harian       1              520
#
# [92 rows x 4 columns]

# %%
#plotting jumlah kumulatif meninggal
meninggal.plot(x='tanggal',y='jumlahkumulatif', kind = 'line',color = 'red',figsize=(10,5))
plt.show()

# %%
#jumlah kumulatif sembuh
sembuh = df[df['diagnosa'] =='Sembuh Harian']
sembuh
# Out:
#         tanggal       diagnosa  jumlah  jumlahkumulatif
# 1    2020-03-01  Sembuh Harian       0                0
# 4    2020-03-02  Sembuh Harian       0                0
# 7    2020-03-03  Sembuh Harian       0                0
# 10   2020-03-04  Sembuh Harian       0                0
# 13   2020-03-05  Sembuh Harian       0                0
# ..          ...            ...     ...              ...
# 262  2020-05-27  Sembuh Harian      20             1698
# 265  2020-05-28  Sembuh Harian      21             1719
# 268  2020-05-29  Sembuh Harian      88             1807
# 271  2020-05-30  Sembuh Harian     196             2003
# 274  2020-05-31  Sembuh Harian      99             2102
#
# [92 rows x 4 columns]

# %%
#plotting jumlah kumulatif sembuh
sembuh.plot(x='tanggal',y='jumlahkumulatif', kind = 'line',color = 'green',figsize=(10,5))
plt.show()

# %%
#plotting jumlah kumulatif keseluruhan
plt.figure(figsize=(20,10))
plt.plot(positif.tanggal,positif.jumlahkumulatif, color = 'blue')
plt.plot(meninggal.tanggal,meninggal.jumlahkumulatif, color = 'red')
plt.plot(sembuh.tanggal,sembuh.jumlahkumulatif, color = 'green')
plt.legend(['Positif','Meninggal','Sembuh'])
plt.xticks(rotation=90)
plt.show()
